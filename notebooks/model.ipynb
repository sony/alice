# %%
import os
if '_cwd_set' not in locals(): locals()['_cwd_set'] = os.chdir(os.path.dirname(os.getcwd()))
import omnifig as fig
fig.initialize()
from src.jimports import *
from src.util import set_default_device, repo_root, data_root
device = set_default_device();
# Out:
# Selecting CUDA device 0 with 33390 MiB free memory and 100% utilization

# %%
cfg = fig.create_config('supexp')

# %%
enc = cfg.pull('decoder')
enc
# Out:
# | CREATING decoder type='mlp'
# |  > hidden --> ..dec-hidden --> .hidden: [512, 512] (reuse)
# |  > .nonlin: 'mish'
# |  > output-nonlin: None (by default)
# |  > input-dim: None (by default)
# |  > output-dim: None (by default)
# |  > gap: None (by default)
# |  > app: None (by default)
# MLP()

# %%
model = cfg.pull('model')
# Out:
# | CREATING model type='supcon-autoencoder'
# |  > .encoder: MLP() (reuse)
# |  > .decoder: MLP() (reuse)
# |  > CREATING .classifier type='mlp'
# |  > hidden --> ..cls-hidden [list with 1 element]
# |  > (0): 256
# |  > .nonlin: 'mish'
# |  > output-nonlin: None (by default)
# |  > input-dim: None (by default)
# |  > output-dim: None (by default)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = cfg.pull('model')
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/abstract.py:105, in AbstractConfig.pull(self, query, default, silent)
#      90 def pull(self, query: Optional[str] = None, default: Optional[Any] = _empty_default, *,
#      91          silent: Optional[bool] = None) -> Any:
#      92 	'''
#      93 	Returns the value found by searching for the query in the config object.
#      94
#    (...)
#     103
#     104 	'''
# --> 105 	return self.pulls(query, default=default, silent=silent)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1078, in ConfigNode.pulls(self, default, silent, *queries, **kwargs)
#    1055 def pulls(self, *queries: str, default: Optional[Any] = AbstractConfig._empty_default,
#    1056           silent: Optional[bool] = None, **kwargs) -> Any:
#    1057 	'''
#    1058 	Searches in the config based on the given queries and returns the product of the resulting node.
#    1059 	The product is the value that node contains, which can be a primitive, a container, or a component.
#    (...)
#    1076
#    1077 	'''
# -> 1078 	return self.search(*queries, default=default, **kwargs).find_product(silent=silent)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:281, in ConfigNode.Search.find_product(self, silent)
#     278 		old = node._trace
#     279 		node._trace = self
#     280 		result = node._create(silent=silent) if self.force_create \
# --> 281 			else node._process(silent=silent)
#     282 		node._trace = old
#     283 return result
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1583, in ConfigNode._process(self, component_args, component_kwargs, silent, **kwargs)
#    1581 assert not (force_create and not allow_create), f'Cannot force create without allowing create: {self}'
#    1582 if (allow_create and self._product is None) or force_create:
# -> 1583 	self._product = self._create(component_args, component_kwargs, silent=silent, **kwargs)
#    1584 else:
#    1585 	self.reporter.reuse_product(self, self._product, silent=silent)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1557, in ConfigNode._create(self, component_args, component_kwargs, silent, creator, **kwargs)
#    1554 	creator = self.settings.get('creator')
#    1555 creator = self.DefaultCreator if creator is None else self.project.find_artifact('creator', creator).cls
#    1556 out = creator(self, silent=silent, project=self.project,  **kwargs)\
# -> 1557 	.create_product(self, args=component_args, kwargs=component_kwargs, silent=silent)
#    1558 return out
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1006, in ConfigNode.DefaultCreator.create_product(self, config, args, kwargs, silent)
#    1004 		value = self._create_container(config, silent=silent)
#    1005 else:
# -> 1006 	value = self._create_component(config, args=args, kwargs=kwargs, silent=silent)
#    1008 self._end_context(config, value)
#    1009 return value
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:854, in ConfigNode.DefaultCreator._create_component(self, config, args, kwargs, silent)
#     850 cls = self._modify_component(self.component_entry,
#     851                              [self.project.find_artifact('modifier', mod) for mod in self.modifiers])
#     853 if isinstance(cls, type) and issubclass(cls, AbstractConfigurable):
# --> 854 	obj = cls.init_from_config(config, args, kwargs, silent=silent)
#     855 else:
#     856 	settings = config.settings
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:196, in Configurable.init_from_config(cls, config, args, kwargs, silent)
#     194 if kwargs is None:
#     195 	kwargs = {}
# --> 196 return cls._config_builder(config, silent=silent).build(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:160, in Configurable._config_builder_type.build(self, *args, **kwargs)
#     156 init_capture = dynamic_capture(self.configurable_parents(self.product), self.fixer, '__init__').activate()
#     158 self.product._my_config = self.config
# --> 160 obj = self.product(*args, **kwargs)
#     162 del self.product._my_config
#     163 obj._my_config = self.config
#
# File ~/miniconda3/lib/python3.12/site-packages/omnibelt/tricks.py:472, in dynamic_capture.capture_context.__call__(self, *args, **kwargs)
#     470 def __call__(self, *args, **kwargs):
#     471 	# assert self.instance is not None, 'cannot call a captured method without an instance'
# --> 472 	return self.fn(self.owner, self.method_fn, self.instance, args, kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:150, in Configurable._config_builder_type.fixer(self, owner, method, obj, args, kwargs)
#     147 self.aliases = getattr(method, '_my_config_aliases', {})
#     148 self.silences = getattr(method, '_my_silent_config', None)
# --> 150 fixed_args, fixed_kwargs = self.fix_args(method, obj, args, kwargs)
#     151 return method(*fixed_args, **fixed_kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:122, in Configurable._config_builder_type.fix_args(self, method, obj, args, kwargs)
#     107 def fix_args(self, method: Callable, obj: Any, args: Tuple, kwargs: Dict[str, Any]) \
#     108 		-> Tuple[Tuple, Dict[str, Any]]:
#     109 	'''
#     110 	Fills in the missing arguments from the config given the method signature
#     111
#    (...)
#     120
#     121 	'''
# --> 122 	fixed_args, fixed_kwargs, missing = extract_function_signature(method, (obj, *args), kwargs,
#     123 	                                                               default_fn=self.find_missing_arg,
#     124 	                                                               include_missing=True)
#     125 	if len(missing):
#     126 		raise self.MissingConfigError(type(obj), missing, config=self.config)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnibelt/tricks.py:1310, in extract_function_signature(fn, args, kwargs, default_fn, include_missing, allow_rest, allow_positional, force_no_positional, skip_first)
#    1308 		fixed_kwargs[n] = p.default
#    1309 else:
# -> 1310 	val = default_fn(n, p)
#    1311 	if val is p:
#    1312 		val = p.default
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:103, in Configurable._config_builder_type.find_missing_arg(self, name, default)
#     101 	if default is self.config._empty_default:
#     102 		default = () if name == 'args' else {}
# --> 103 out = self.config.pulls(name.replace('_', '-'), *aliases, default=default, silent=silent)
#     104 return out
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1078, in ConfigNode.pulls(self, default, silent, *queries, **kwargs)
#    1055 def pulls(self, *queries: str, default: Optional[Any] = AbstractConfig._empty_default,
#    1056           silent: Optional[bool] = None, **kwargs) -> Any:
#    1057 	'''
#    1058 	Searches in the config based on the given queries and returns the product of the resulting node.
#    1059 	The product is the value that node contains, which can be a primitive, a container, or a component.
#    (...)
#    1076
#    1077 	'''
# -> 1078 	return self.search(*queries, default=default, **kwargs).find_product(silent=silent)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:281, in ConfigNode.Search.find_product(self, silent)
#     278 		old = node._trace
#     279 		node._trace = self
#     280 		result = node._create(silent=silent) if self.force_create \
# --> 281 			else node._process(silent=silent)
#     282 		node._trace = old
#     283 return result
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1583, in ConfigNode._process(self, component_args, component_kwargs, silent, **kwargs)
#    1581 assert not (force_create and not allow_create), f'Cannot force create without allowing create: {self}'
#    1582 if (allow_create and self._product is None) or force_create:
# -> 1583 	self._product = self._create(component_args, component_kwargs, silent=silent, **kwargs)
#    1584 else:
#    1585 	self.reporter.reuse_product(self, self._product, silent=silent)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1557, in ConfigNode._create(self, component_args, component_kwargs, silent, creator, **kwargs)
#    1554 	creator = self.settings.get('creator')
#    1555 creator = self.DefaultCreator if creator is None else self.project.find_artifact('creator', creator).cls
#    1556 out = creator(self, silent=silent, project=self.project,  **kwargs)\
# -> 1557 	.create_product(self, args=component_args, kwargs=component_kwargs, silent=silent)
#    1558 return out
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:1006, in ConfigNode.DefaultCreator.create_product(self, config, args, kwargs, silent)
#    1004 		value = self._create_container(config, silent=silent)
#    1005 else:
# -> 1006 	value = self._create_component(config, args=args, kwargs=kwargs, silent=silent)
#    1008 self._end_context(config, value)
#    1009 return value
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/config/nodes.py:854, in ConfigNode.DefaultCreator._create_component(self, config, args, kwargs, silent)
#     850 cls = self._modify_component(self.component_entry,
#     851                              [self.project.find_artifact('modifier', mod) for mod in self.modifiers])
#     853 if isinstance(cls, type) and issubclass(cls, AbstractConfigurable):
# --> 854 	obj = cls.init_from_config(config, args, kwargs, silent=silent)
#     855 else:
#     856 	settings = config.settings
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:196, in Configurable.init_from_config(cls, config, args, kwargs, silent)
#     194 if kwargs is None:
#     195 	kwargs = {}
# --> 196 return cls._config_builder(config, silent=silent).build(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:160, in Configurable._config_builder_type.build(self, *args, **kwargs)
#     156 init_capture = dynamic_capture(self.configurable_parents(self.product), self.fixer, '__init__').activate()
#     158 self.product._my_config = self.config
# --> 160 obj = self.product(*args, **kwargs)
#     162 del self.product._my_config
#     163 obj._my_config = self.config
#
# File ~/miniconda3/lib/python3.12/site-packages/omnibelt/tricks.py:472, in dynamic_capture.capture_context.__call__(self, *args, **kwargs)
#     470 def __call__(self, *args, **kwargs):
#     471 	# assert self.instance is not None, 'cannot call a captured method without an instance'
# --> 472 	return self.fn(self.owner, self.method_fn, self.instance, args, kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:151, in Configurable._config_builder_type.fixer(self, owner, method, obj, args, kwargs)
#     148 self.silences = getattr(method, '_my_silent_config', None)
#     150 fixed_args, fixed_kwargs = self.fix_args(method, obj, args, kwargs)
# --> 151 return method(*fixed_args, **fixed_kwargs)
#
# File ~/workspace/remote/src/models.py:250, in MLP.__init__(self, hidden, nonlin, output_nonlin, input_dim, output_dim, **kwargs)
#     246 def __init__(self, hidden: Optional[Iterable[int]] = None, *,
#     247 			 nonlin: str = 'elu', output_nonlin: Optional[str] = None,
#     248 			 input_dim: Optional[int] = None, output_dim: Optional[int] = None,
#     249 			 **kwargs):
# --> 250 	super().__init__(hidden=hidden, nonlin=nonlin, output_nonlin=output_nonlin, input_dim=input_dim, output_dim=output_dim, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnibelt/tricks.py:472, in dynamic_capture.capture_context.__call__(self, *args, **kwargs)
#     470 def __call__(self, *args, **kwargs):
#     471 	# assert self.instance is not None, 'cannot call a captured method without an instance'
# --> 472 	return self.fn(self.owner, self.method_fn, self.instance, args, kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:150, in Configurable._config_builder_type.fixer(self, owner, method, obj, args, kwargs)
#     147 self.aliases = getattr(method, '_my_config_aliases', {})
#     148 self.silences = getattr(method, '_my_silent_config', None)
# --> 150 fixed_args, fixed_kwargs = self.fix_args(method, obj, args, kwargs)
#     151 return method(*fixed_args, **fixed_kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnifig/configurable.py:122, in Configurable._config_builder_type.fix_args(self, method, obj, args, kwargs)
#     107 def fix_args(self, method: Callable, obj: Any, args: Tuple, kwargs: Dict[str, Any]) \
#     108 		-> Tuple[Tuple, Dict[str, Any]]:
#     109 	'''
#     110 	Fills in the missing arguments from the config given the method signature
#     111
#    (...)
#     120
#     121 	'''
# --> 122 	fixed_args, fixed_kwargs, missing = extract_function_signature(method, (obj, *args), kwargs,
#     123 	                                                               default_fn=self.find_missing_arg,
#     124 	                                                               include_missing=True)
#     125 	if len(missing):
#     126 		raise self.MissingConfigError(type(obj), missing, config=self.config)
#
# File ~/miniconda3/lib/python3.12/site-packages/omnibelt/tricks.py:1236, in extract_function_signature(fn, args, kwargs, default_fn, include_missing, allow_rest, allow_positional, force_no_positional, skip_first)
#    1233 	fn = fn.__init__
#    1234 	skip_first = skip_first is not False
# -> 1236 params = inspect.signature(fn).parameters
#    1237 if skip_first:
#    1238 	params = list(params.values())[1:]
#
# File ~/miniconda3/lib/python3.12/inspect.py:3335, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3333 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3334     """Get a signature object for the passed callable."""
# -> 3335     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3336                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/lib/python3.12/inspect.py:3075, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3071 @classmethod
#    3072 def from_callable(cls, obj, *,
#    3073                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3074     """Constructs Signature for the given callable object."""
# -> 3075     return _signature_from_callable(obj, sigcls=cls,
#    3076                                     follow_wrapper_chains=follow_wrapped,
#    3077                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/lib/python3.12/inspect.py:2592, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2587     return _signature_from_function(sigcls, obj,
#    2588                                     skip_bound_arg=skip_bound_arg,
#    2589                                     globals=globals, locals=locals, eval_str=eval_str)
#    2591 if _signature_is_builtin(obj):
# -> 2592     return _signature_from_builtin(sigcls, obj,
#    2593                                    skip_bound_arg=skip_bound_arg)
#    2595 if isinstance(obj, functools.partial):
#    2596     wrapped_sig = _get_signature_of(obj.func)
#
# File ~/miniconda3/lib/python3.12/inspect.py:2382, in _signature_from_builtin(cls, func, skip_bound_arg)
#    2380 s = getattr(func, "__text_signature__", None)
#    2381 if not s:
# -> 2382     raise ValueError("no signature found for builtin {!r}".format(func))
#    2384 return _signature_fromstr(cls, func, s, skip_bound_arg)
#
# ValueError: no signature found for builtin <omnibelt.tricks.dynamic_capture.capture_context object at 0x7f62b56cc710>
